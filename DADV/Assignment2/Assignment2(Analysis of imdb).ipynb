# %%
import numpy as np
import pandas as pd

# %%
basics = pd.read_csv("C:\\Users\\aishwarya\\Desktop\\Data Mining\\DADV\\Assignments\\Basics_data.tsv", delimiter = "\t")
basics.to_csv('title_basics_data_csv.csv')
basics.head(10)
# Out:
# C:\Users\aishwarya\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       tconst titleType                                 primaryTitle  \
# 0  tt0000001     short                                   Carmencita
# 1  tt0000002     short                       Le clown et ses chiens
# 2  tt0000003     short                               Pauvre Pierrot
# 3  tt0000004     short                                  Un bon bock
# 4  tt0000005     short                             Blacksmith Scene
# 5  tt0000006     short                            Chinese Opium Den
# 6  tt0000007     short  Corbett and Courtney Before the Kinetograph
# 7  tt0000008     short       Edison Kinetoscopic Record of a Sneeze
# 8  tt0000009     short                                   Miss Jerry
# 9  tt0000010     short                          Leaving the Factory
#
#                                  originalTitle isAdult startYear endYear  \
# 0                                   Carmencita       0      1894      \N
# 1                       Le clown et ses chiens       0      1892      \N
# 2                               Pauvre Pierrot       0      1892      \N
# 3                                  Un bon bock       0      1892      \N
# 4                             Blacksmith Scene       0      1893      \N
# 5                            Chinese Opium Den       0      1894      \N
# 6  Corbett and Courtney Before the Kinetograph       0      1894      \N
# 7       Edison Kinetoscopic Record of a Sneeze       0      1894      \N
# 8                                   Miss Jerry       0      1894      \N
# 9          La sortie de l'usine Lumière à Lyon       0      1895      \N
#
#   runtimeMinutes                    genres
# 0              1         Documentary,Short
# 1              5           Animation,Short
# 2              4  Animation,Comedy,Romance
# 3             12           Animation,Short
# 4              1              Comedy,Short
# 5              1                     Short
# 6              1               Short,Sport
# 7              1         Documentary,Short
# 8             40             Romance,Short
# 9              1         Documentary,Short

# %%
ratings = pd.read_csv("C:\\Users\\aishwarya\\Desktop\\Data Mining\\DADV\\Assignments\\title.basics\\data.tsv", delimiter = "\t")
ratings.to_csv('rating_csv.csv')
ratings.head(5)
# Out:
# C:\Users\aishwarya\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
basics['startYear'] = pd.to_numeric(basics['startYear'], errors='coerce')

# %%
year = basics[(basics['startYear'] >= 2000) & (basics['startYear'] <= 2009) & (basics['titleType'] == "movie")]
year.head(10)
# Out:
#            tconst titleType                primaryTitle  \
# 15184   tt0015414     movie      La tierra de los toros
# 34811   tt0035423     movie              Kate & Leopold
# 63462   tt0064730     movie  Japan Organized Crime Boss
# 85714   tt0087608     movie            Leila wa al ziap
# 86825   tt0088751     movie           The Naked Monster
# 93967   tt0096056     movie        Crime and Punishment
# 95409   tt0097540     movie                    Responso
# 100116  tt0102362     movie                      Istota
# 105368  tt0107706     movie                     Nothing
# 106192  tt0108549     movie  West from North Goes South
#
#                      originalTitle isAdult  startYear endYear runtimeMinutes  \
# 15184       La tierra de los toros       0     2000.0      \N             60
# 34811               Kate & Leopold       0     2001.0      \N            118
# 63462   Nihon boryoku-dan: Kumicho       0     2000.0      \N             97
# 85714             Leila wa al ziap       0     2008.0      \N             90
# 86825            The Naked Monster       0     2005.0      \N            100
# 93967         Crime and Punishment       0     2002.0      \N            126
# 95409                     Responso       0     2004.0      \N             81
# 100116                      Istota       0     2000.0      \N             80
# 105368                     Nothing       0     2000.0      \N             \N
# 106192  West from North Goes South       0     2004.0      \N             96
#
#                         genres
# 15184                       \N
# 34811   Comedy,Fantasy,Romance
# 63462             Action,Crime
# 85714              Documentary
# 86825     Comedy,Horror,Sci-Fi
# 93967                    Drama
# 95409                       \N
# 100116           Drama,Romance
# 105368                      \N
# 106192          Comedy,Mystery

# %%
merge = pd.merge(year, ratings, on='tconst')
merge.head(10)
# Out:
#       tconst titleType                primaryTitle  \
# 0  tt0015414     movie      La tierra de los toros
# 1  tt0035423     movie              Kate & Leopold
# 2  tt0064730     movie  Japan Organized Crime Boss
# 3  tt0087608     movie            Leila wa al ziap
# 4  tt0088751     movie           The Naked Monster
# 5  tt0096056     movie        Crime and Punishment
# 6  tt0097540     movie                    Responso
# 7  tt0102362     movie                      Istota
# 8  tt0108549     movie  West from North Goes South
# 9  tt0109173     movie            Auf allen Meeren
#
#                 originalTitle isAdult  startYear endYear runtimeMinutes  \
# 0      La tierra de los toros       0     2000.0      \N             60
# 1              Kate & Leopold       0     2001.0      \N            118
# 2  Nihon boryoku-dan: Kumicho       0     2000.0      \N             97
# 3            Leila wa al ziap       0     2008.0      \N             90
# 4           The Naked Monster       0     2005.0      \N            100
# 5        Crime and Punishment       0     2002.0      \N            126
# 6                    Responso       0     2004.0      \N             81
# 7                      Istota       0     2000.0      \N             80
# 8  West from North Goes South       0     2004.0      \N             96
# 9            Auf allen Meeren       0     2002.0      \N             95
#
#                    genres  averageRating  numVotes
# 0                      \N            5.4        11
# 1  Comedy,Fantasy,Romance            6.4     78723
# 2            Action,Crime            7.0       172
# 3             Documentary            7.7        13
# 4    Comedy,Horror,Sci-Fi            5.4       274
# 5                   Drama            5.8       641
# 6                      \N            7.4         5
# 7           Drama,Romance            4.8        10
# 8          Comedy,Mystery            7.7        23
# 9             Documentary            7.8        26

# %%
popular_movies =  merge.sort_values('numVotes', ascending = False)
popular_movies.head(10)
# Out:
#           tconst titleType                                       primaryTitle  \
# 19847  tt0468569     movie                                    The Dark Knight
# 64     tt0120737     movie  The Lord of the Rings: The Fellowship of the Ring
# 349    tt0167260     movie      The Lord of the Rings: The Return of the King
# 350    tt0167261     movie              The Lord of the Rings: The Two Towers
# 400    tt0172495     movie                                          Gladiator
# 11559  tt0372784     movie                                      Batman Begins
# 10547  tt0361748     movie                               Inglourious Basterds
# 14549  tt0407887     movie                                       The Departed
# 21232  tt0482571     movie                                       The Prestige
# 1020   tt0209144     movie                                            Memento
#
#                                            originalTitle isAdult  startYear  \
# 19847                                    The Dark Knight       0     2008.0
# 64     The Lord of the Rings: The Fellowship of the Ring       0     2001.0
# 349        The Lord of the Rings: The Return of the King       0     2003.0
# 350                The Lord of the Rings: The Two Towers       0     2002.0
# 400                                            Gladiator       0     2000.0
# 11559                                      Batman Begins       0     2005.0
# 10547                               Inglourious Basterds       0     2009.0
# 14549                                       The Departed       0     2006.0
# 21232                                       The Prestige       0     2006.0
# 1020                                             Memento       0     2000.0
#
#       endYear runtimeMinutes                  genres  averageRating  numVotes
# 19847      \N            152      Action,Crime,Drama            9.0   2288140
# 64         \N            178  Action,Adventure,Drama            8.8   1649550
# 349        \N            201  Action,Adventure,Drama            8.9   1632805
# 350        \N            179  Action,Adventure,Drama            8.7   1476251
# 400        \N            155  Action,Adventure,Drama            8.5   1333117
# 11559      \N            140        Action,Adventure            8.2   1300916
# 10547      \N            153     Adventure,Drama,War            8.3   1257816
# 14549      \N            151    Crime,Drama,Thriller            8.5   1181716
# 21232      \N            130    Drama,Mystery,Sci-Fi            8.5   1181694
# 1020       \N            113        Mystery,Thriller            8.4   1119291

# %%
popular_movies.head(10)['averageRating'].mean()
# Out:
# 8.580000000000002

# %%
votes = ratings[ratings['numVotes'] >= 1000]
votes.head(10)
# Out:
#        tconst  averageRating  numVotes
# 0   tt0000001            5.7      1669
# 2   tt0000003            6.5      1392
# 4   tt0000005            6.2      2181
# 7   tt0000008            5.4      1838
# 9   tt0000010            6.9      6152
# 11  tt0000012            7.4     10544
# 12  tt0000013            5.7      1598
# 13  tt0000014            7.1      4706
# 15  tt0000016            5.9      1221
# 21  tt0000023            5.7      1164

# %%
merge2 = pd.merge(basics, votes, on = 'tconst')
merge2.head(10)
# Out:
#       tconst titleType                                 primaryTitle  \
# 0  tt0000001     short                                   Carmencita
# 1  tt0000003     short                               Pauvre Pierrot
# 2  tt0000005     short                             Blacksmith Scene
# 3  tt0000008     short       Edison Kinetoscopic Record of a Sneeze
# 4  tt0000010     short                          Leaving the Factory
# 5  tt0000012     short                       The Arrival of a Train
# 6  tt0000013     short  The Photographical Congress Arrives in Lyon
# 7  tt0000014     short                          The Waterer Watered
# 8  tt0000016     short                       Barque sortant du port
# 9  tt0000023     short                                      The Sea
#
#                                        originalTitle isAdult  startYear  \
# 0                                         Carmencita       0     1894.0
# 1                                     Pauvre Pierrot       0     1892.0
# 2                                   Blacksmith Scene       0     1893.0
# 3             Edison Kinetoscopic Record of a Sneeze       0     1894.0
# 4                La sortie de l'usine Lumière à Lyon       0     1895.0
# 5                   L'arrivée d'un train à La Ciotat       0     1896.0
# 6  Neuville-sur-Saône: Débarquement du congrès de...       0     1895.0
# 7                                  L'arroseur arrosé       0     1895.0
# 8                             Barque sortant du port       0     1895.0
# 9                                    Baignade en mer       0     1895.0
#
#   endYear runtimeMinutes                    genres  averageRating  numVotes
# 0      \N              1         Documentary,Short            5.7      1669
# 1      \N              4  Animation,Comedy,Romance            6.5      1392
# 2      \N              1              Comedy,Short            6.2      2181
# 3      \N              1         Documentary,Short            5.4      1838
# 4      \N              1         Documentary,Short            6.9      6152
# 5      \N              1         Documentary,Short            7.4     10544
# 6      \N              1         Documentary,Short            5.7      1598
# 7      \N              1              Comedy,Short            7.1      4706
# 8      \N              1         Documentary,Short            5.9      1221
# 9      \N              1         Documentary,Short            5.7      1164

# %%
year2 = merge2[(merge2['startYear'] >= 1900) & (merge2['startYear'] < 2000) & (merge2['titleType'] == "movie")]
year2.head(10)
# Out:
#        tconst titleType                                       primaryTitle  \
# 41  tt0002130     movie                                    Dante's Inferno
# 45  tt0002844     movie          Fantômas: In the Shadow of the Guillotine
# 46  tt0003037     movie                         Fantomas: The Man in Black
# 47  tt0003165     movie                  Fantômas: The Dead Man Who Killed
# 48  tt0003419     movie                              The Student of Prague
# 50  tt0003643     movie  The Avenging Conscience: or 'Thou Shalt Not Kill'
# 52  tt0003740     movie                                            Cabiria
# 55  tt0003930     movie              Fantomas: The Mysterious Finger Print
# 58  tt0004026     movie                                          The Golem
# 60  tt0004181     movie                                 Judith of Bethulia
#
#                                         originalTitle isAdult  startYear  \
# 41                                          L'Inferno       0     1911.0
# 45              Fantômas - À l'ombre de la guillotine       0     1913.0
# 46                               Juve contre Fantômas       0     1913.0
# 47                                    Le mort qui tue       0     1913.0
# 48                               Der Student von Prag       0     1913.0
# 50  The Avenging Conscience: or 'Thou Shalt Not Kill'       0     1914.0
# 52                                            Cabiria       0     1914.0
# 55                           Fantômas contre Fantômas       0     1914.0
# 58                                          Der Golem       0     1915.0
# 60                                 Judith of Bethulia       0     1914.0
#
#    endYear runtimeMinutes                   genres  averageRating  numVotes
# 41      \N             71  Adventure,Drama,Fantasy            7.0      2334
# 45      \N             54              Crime,Drama            7.0      1976
# 46      \N             61              Crime,Drama            7.0      1369
# 47      \N             90      Crime,Drama,Mystery            7.0      1071
# 48      \N             85     Drama,Fantasy,Horror            6.5      1823
# 50      \N             78       Crime,Drama,Horror            6.4      1134
# 52      \N            148  Adventure,Drama,History            7.1      3155
# 55      \N             59              Crime,Drama            6.9      1177
# 58      \N             60                   Horror            6.8      1053
# 60      \N             61                    Drama            6.1      1252

# %%
result = year2.groupby('startYear').agg(values = ('averageRating', np.mean)).reset_index()
result
# Out:
#     startYear    values
# 0      1911.0  7.000000
# 1      1913.0  6.875000
# 2      1914.0  6.560000
# 3      1915.0  6.760000
# 4      1916.0  6.950000
# ..        ...       ...
# 83     1995.0  6.428307
# 84     1996.0  6.327020
# 85     1997.0  6.416018
# 86     1998.0  6.425166
# 87     1999.0  6.412863
#
# [88 rows x 2 columns]

# %%
maximum = 0
final_year = 0
for i in range(1, len(result)):
    x = result.loc[i, 'values']
    y = result.loc[i-1, 'values']
    temp = abs(x - y)
    if (temp > maximum):
        maximum = temp
        final_year = result.loc[[i], ['startYear']]
final_year
# Out:
#     startYear
# 17     1929.0

# %%
merge2.head(10)
# Out:
#       tconst titleType                                 primaryTitle  \
# 0  tt0000001     short                                   Carmencita
# 1  tt0000003     short                               Pauvre Pierrot
# 2  tt0000005     short                             Blacksmith Scene
# 3  tt0000008     short       Edison Kinetoscopic Record of a Sneeze
# 4  tt0000010     short                          Leaving the Factory
# 5  tt0000012     short                       The Arrival of a Train
# 6  tt0000013     short  The Photographical Congress Arrives in Lyon
# 7  tt0000014     short                          The Waterer Watered
# 8  tt0000016     short                       Barque sortant du port
# 9  tt0000023     short                                      The Sea
#
#                                        originalTitle isAdult  startYear  \
# 0                                         Carmencita       0     1894.0
# 1                                     Pauvre Pierrot       0     1892.0
# 2                                   Blacksmith Scene       0     1893.0
# 3             Edison Kinetoscopic Record of a Sneeze       0     1894.0
# 4                La sortie de l'usine Lumière à Lyon       0     1895.0
# 5                   L'arrivée d'un train à La Ciotat       0     1896.0
# 6  Neuville-sur-Saône: Débarquement du congrès de...       0     1895.0
# 7                                  L'arroseur arrosé       0     1895.0
# 8                             Barque sortant du port       0     1895.0
# 9                                    Baignade en mer       0     1895.0
#
#   endYear runtimeMinutes                    genres  averageRating  numVotes
# 0      \N              1         Documentary,Short            5.7      1669
# 1      \N              4  Animation,Comedy,Romance            6.5      1392
# 2      \N              1              Comedy,Short            6.2      2181
# 3      \N              1         Documentary,Short            5.4      1838
# 4      \N              1         Documentary,Short            6.9      6152
# 5      \N              1         Documentary,Short            7.4     10544
# 6      \N              1         Documentary,Short            5.7      1598
# 7      \N              1              Comedy,Short            7.1      4706
# 8      \N              1         Documentary,Short            5.9      1221
# 9      \N              1         Documentary,Short            5.7      1164

# %%
movies = merge2[merge2['titleType'] == "movie"]
movies
# Out:
#           tconst titleType                               primaryTitle  \
# 41     tt0002130     movie                            Dante's Inferno
# 45     tt0002844     movie  Fantômas: In the Shadow of the Guillotine
# 46     tt0003037     movie                 Fantomas: The Man in Black
# 47     tt0003165     movie          Fantômas: The Dead Man Who Killed
# 48     tt0003419     movie                      The Student of Prague
# ...          ...       ...                                        ...
# 59342  tt9894470     movie                                        VFW
# 59345  tt9898858     movie                            Coffee & Kareem
# 59351  tt9900782     movie                                     Kaithi
# 59352  tt9904802     movie                                Enemy Lines
# 59355  tt9911196     movie                        The Marriage Escape
#
#                                originalTitle isAdult  startYear endYear  \
# 41                                 L'Inferno       0     1911.0      \N
# 45     Fantômas - À l'ombre de la guillotine       0     1913.0      \N
# 46                      Juve contre Fantômas       0     1913.0      \N
# 47                           Le mort qui tue       0     1913.0      \N
# 48                      Der Student von Prag       0     1913.0      \N
# ...                                      ...     ...        ...     ...
# 59342                                    VFW       0     2019.0      \N
# 59345                        Coffee & Kareem       0     2020.0      \N
# 59351                                 Kaithi       0     2019.0      \N
# 59352                            Enemy Lines       0     2020.0      \N
# 59355         De beentjes van Sint-Hildegard       0     2020.0      \N
#
#       runtimeMinutes                   genres  averageRating  numVotes
# 41                71  Adventure,Drama,Fantasy            7.0      2334
# 45                54              Crime,Drama            7.0      1976
# 46                61              Crime,Drama            7.0      1369
# 47                90      Crime,Drama,Mystery            7.0      1071
# 48                85     Drama,Fantasy,Horror            6.5      1823
# ...              ...                      ...            ...       ...
# 59342             92      Action,Crime,Horror            6.1      5255
# 59345             88            Action,Comedy            5.1     11421
# 59351            145          Action,Thriller            8.5     10946
# 59352             92                      War            4.7      1102
# 59355            103             Comedy,Drama            7.7      1044
#
# [32485 rows x 11 columns]

# %%
eachyear = movies.groupby('startYear').agg(avg = ('averageRating', np.mean)).reset_index()
eachyear
# Out:
#      startYear       avg
# 0       1911.0  7.000000
# 1       1913.0  6.875000
# 2       1914.0  6.560000
# 3       1915.0  6.760000
# 4       1916.0  6.950000
# ..         ...       ...
# 104     2016.0  6.187930
# 105     2017.0  6.172457
# 106     2018.0  6.264192
# 107     2019.0  6.300564
# 108     2020.0  6.078772
#
# [109 rows x 2 columns]

# %%
eachyear.tail(10)
# Out:
#      startYear       avg
# 99      2011.0  6.161891
# 100     2012.0  6.145388
# 101     2013.0  6.198552
# 102     2014.0  6.188835
# 103     2015.0  6.184063
# 104     2016.0  6.187930
# 105     2017.0  6.172457
# 106     2018.0  6.264192
# 107     2019.0  6.300564
# 108     2020.0  6.078772

# %%
eachyear = eachyear[eachyear['startYear'] == 2013]
eachyear
# Out:
#      startYear       avg
# 101     2013.0  6.198552

# %%
eachyear.tail(10)
# Out:
#      startYear       avg
# 101     2013.0  6.198552

# %%
from sklearn.linear_model import LinearRegression
x = eachyear['startYear'].values.reshape(-1,1)
y = eachyear['avg'].values.reshape(-1,1)

# %%
model = LinearRegression().fit(x,y)

# %%
xtest = np.array([2013]).reshape(-1,1)
y_pred = model.predict(xtest)
print(y_pred)
# Out:
# [[6.19855196]]

# %%
# Visualization
import matplotlib.pyplot as plt

# %%
pred2 = model.predict(x)
plt.scatter(x, y)
plt.plot(x, pred2, color='red')
plt.show()

# %%
# find the correlation between rank and votes for each year in the 1900s. 
# By how much did the correlation coefficient grow each year? How good is this regression?

# %%
year3 = basics[(basics['startYear']>= 1900) & (basics['startYear'] < 2000) & (basics['titleType'] == "movie")]
year3.head(10)
# Out:
#         tconst titleType                    primaryTitle  \
# 331  tt0000335     movie           Soldiers of the Cross
# 498  tt0000502     movie                        Bohemios
# 570  tt0000574     movie     The Story of the Kelly Gang
# 610  tt0000615     movie              Robbery Under Arms
# 625  tt0000630     movie                          Hamlet
# 668  tt0000675     movie                     Don Quijote
# 672  tt0000679     movie  The Fairylogue and Radio-Plays
# 729  tt0000739     movie       El pastorcito de Torrente
# 783  tt0000793     movie                   Andreas Hofer
# 802  tt0000812     movie               El blocao Velarde
#
#                       originalTitle isAdult  startYear endYear runtimeMinutes  \
# 331           Soldiers of the Cross       0     1900.0      \N             \N
# 498                        Bohemios       0     1905.0      \N            100
# 570     The Story of the Kelly Gang       0     1906.0      \N             70
# 610              Robbery Under Arms       0     1907.0      \N             \N
# 625                          Amleto       0     1908.0      \N             \N
# 668                     Don Quijote       0     1908.0      \N             \N
# 672  The Fairylogue and Radio-Plays       0     1908.0      \N            120
# 729       El pastorcito de Torrente       0     1908.0      \N             \N
# 783                   Andreas Hofer       0     1909.0      \N             \N
# 802               El blocao Velarde       0     1909.0      \N             \N
#
#                     genres
# 331        Biography,Drama
# 498                     \N
# 570  Biography,Crime,Drama
# 610                  Drama
# 625                  Drama
# 668                  Drama
# 672      Adventure,Fantasy
# 729                  Drama
# 783                  Drama
# 802                     \N

# %%
merge3 = pd.merge(ratings, year3, on = 'tconst')
merge3.head(10)
# Out:
#       tconst  averageRating  numVotes titleType  \
# 0  tt0000335            6.0        39     movie
# 1  tt0000502            4.5         8     movie
# 2  tt0000574            6.1       610     movie
# 3  tt0000615            4.5        14     movie
# 4  tt0000630            3.2        11     movie
# 5  tt0000675            4.9         9     movie
# 6  tt0000679            5.2        35     movie
# 7  tt0000739            6.3         7     movie
# 8  tt0000793            5.0         7     movie
# 9  tt0000862            4.5         8     movie
#
#                      primaryTitle                   originalTitle isAdult  \
# 0           Soldiers of the Cross           Soldiers of the Cross       0
# 1                        Bohemios                        Bohemios       0
# 2     The Story of the Kelly Gang     The Story of the Kelly Gang       0
# 3              Robbery Under Arms              Robbery Under Arms       0
# 4                          Hamlet                          Amleto       0
# 5                     Don Quijote                     Don Quijote       0
# 6  The Fairylogue and Radio-Plays  The Fairylogue and Radio-Plays       0
# 7       El pastorcito de Torrente       El pastorcito de Torrente       0
# 8                   Andreas Hofer                   Andreas Hofer       0
# 9                      Faldgruben                      Faldgruben       0
#
#    startYear endYear runtimeMinutes                 genres
# 0     1900.0      \N             \N        Biography,Drama
# 1     1905.0      \N            100                     \N
# 2     1906.0      \N             70  Biography,Crime,Drama
# 3     1907.0      \N             \N                  Drama
# 4     1908.0      \N             \N                  Drama
# 5     1908.0      \N             \N                  Drama
# 6     1908.0      \N            120      Adventure,Fantasy
# 7     1908.0      \N             \N                  Drama
# 8     1909.0      \N             \N                  Drama
# 9     1909.0      \N             \N                     \N

# %%
years = list(merge3['startYear'].unique())
Corr_year = pd.DataFrame()
for year in years:
    X = merge3[merge3['startYear']==year].iloc[:,[1,2]]
    corr = X.corr()
    corr = corr['averageRating'][1]
    newRow = {'Correlation':corr,'Year':year}
    Corr_year = Corr_year.append(newRow, ignore_index=True)
Corr_year = Corr_year.reindex(columns=['Year', 'Correlation'])
Corr_year
# Out:
#       Year  Correlation
# 0   1900.0    -0.189051
# 1   1905.0     0.329072
# 2   1906.0     0.910208
# 3   1907.0    -0.065269
# 4   1908.0    -0.055815
# ..     ...          ...
# 95  1997.0     0.105793
# 96  1903.0     0.739733
# 97  1902.0    -0.316438
# 98  1904.0     0.579870
# 99  1901.0    -1.000000
#
# [100 rows x 2 columns]
